# %%
from math import inf as infinity
import math
import random
import copy
DYNAMIC = 1
OPPONENT = 2
import numpy as np
initial_epsilon = 0.1
q_values = {}
dynamic_score = 0
opponent_score = 0


size = int(input('Size of the board '))
n = int(input('How many components in a line to win '))
number_of_games = int(input('Number of matches '))

board = [[0 for _ in range(size)] for _ in range(size)]

def game_over(state):
    return wins(state, DYNAMIC) or wins(state, OPPONENT)

def empty_cells(state):
    empty = []
    for x, row in enumerate(state):
        for y, col in enumerate(row):
            if col == 0:
                empty.append([x,y])
    return empty

def valid_move(x,y):
    global board
    if board[x][y] == 0:
        return True
    return False

def wins(state, player):
    for row in state:
        for i in range(len(row) - n + 1):
            if all(row[i+k] == player for k in range(n)):
                return True

    for i in range(len(state)):
        for j in range (len(state) - n + 1):
            if all(state[j+k][i] == player for k in range(n)):
                return True
            
    for i in range(len(state) - n + 1):
        for j in range(len(state[0]) -n + 1):
            if all(state[j + k] [i] == player for k in range(n)):
                return True
    for i in range(len(state) -n + 1):
        for j in range (n - 1, len(state[0])):
            if all(state[i+k][j-k] == player for k in range(n)):
                return True
    return False

def find_open_n(state, player):
    for row in state:
        for i in range(len(row) - n + 1):
            if all(row[i+k] == player for k in range(n)):
                if (i - 1>= 0 and row[i-1] == 0) and (i + n < len(row) and row[i+n] == 0):
                    return True

    for row in state:
        for j in range (len(row) - n + 1):
            if all(state[i+k][i] == player for k in range(n)):
                if (j - 1>= 0 and state[j-1][i] == 0) and (j + n < len(state) and state[j+n][i] == 0):
                    return True

    for i in range(len(state) -n + 1):
        for j in range(len(state[0]) - n + 1):
            if all(state[i+k][j+k] == player for k in range(n)):
                if (i - 1 >= 0 and j - 1 >= 0 and state[i-1][j-1] == 0) and (i + n < len(state) and j + n < len(state[0]) and state[i+n][j+n] == 0):
                    return True

    for i in range(len(state) - n + 1):
        for j in range(n-1, len(state[0])):
            if all(state[i + k][j - k] == player for k in range(n)):
                if (i - 1 >= 0 and j + 1 < len(state[0]) and state[i-1][j+1] == 0) and (i + n < len(state) and j - n >= 0 and state[i+n][j-n] == 0):
                    return True
    return False

def check_3(state, player):
    score = 0
    for row in state:
        for i in range(len(row) - 2):
            if all(row[i+k] == player for k in range(3)):
                score += 45
    
    for i in range(len(state)):
        for j in range(len(state) - 2):
            if all(state[j+k][i] == player for k in range(3)):
                score += 45
    
    for i in range (len(state) - 2):
        for j in range(len(state[0]) - 2):
            if all(state[i+k][j+k] == player for k in range(3)):
                score += 45

    for i in range(len(state) - 2):
        for j in range(2, len(state[0])):
            if all (state[i+k][j -k] ==player for k in range(3)):
                score += 45

    return score

def check_2(state, player):
    score = 0
    # Check row
    for row in state:
        for i in range(len(row) - 1):
            if all(row[i + k] == player for k in range(2)):
                score += 20

    # Check col
    for i in range(len(state)):
        for j in range(len(state) - 1):
            if all(state[j + k][i] == player for k in range(2)):
                score += 20

    # Check diagonal (top-left to bottom-right)
    for i in range(len(state) - 1):
        for j in range(len(state[0]) - 1):
            if all(state[i + k][j + k] == player for k in range(2)):
                score += 20

    # Check diagonal (top-right to bottom-left)
    for i in range(len(state) - 1):
        for j in range(1, len(state[0])):
            if all(state[i + k][j - k] == player for k in range(2)):
                score += 20

    return score

def def_3(state, player, opponent):
    score = 0
    # Check row
    for row in state:
        for i in range(len(row) - 2):
            if all(row[i + k] == player for k in range(3)):
                # Check bounds for left and right blocking
                left_blocked = i > 0 and row[i - 1] == opponent
                right_blocked = i + 3 < len(row) and row[i + 3] == opponent
                if left_blocked or right_blocked:
                    score += 60

    # Check col
    for i in range(len(state)):
        for j in range(len(state) - 2):
            if all(state[j + k][i] == player for k in range(3)):
                # Check bounds for top and bottom blocking
                top_blocked = j > 0 and state[j - 1][i] == opponent
                bottom_blocked = j + 3 < len(state) and state[j + 3][i] == opponent
                if top_blocked or bottom_blocked:
                    score += 60

    # Check diagonal (top-left to bottom-right)
    for i in range(len(state) - 2):
        for j in range(len(state[0]) - 2):
            if all(state[i + k][j + k] == player for k in range(3)):
                # Check bounds for top-left and bottom-right blocking
                top_left_blocked = i > 0 and j > 0 and state[i - 1][j - 1] == opponent
                bottom_right_blocked = i + 3 < len(state) and j + 3 < len(state[0]) and state[i + 3][j + 3] == opponent
                if top_left_blocked or bottom_right_blocked:
                    score += 60

    # Check diagonal (top-right to bottom-left)
    for i in range(len(state) - 2):
        for j in range(2, len(state[0])):
            if all(state[i + k][j - k] == player for k in range(3)):
                # Check bounds for top-right and bottom-left blocking
                top_right_blocked = i > 0 and j + 1 < len(state[0]) and state[i - 1][j + 1] == opponent
                bottom_left_blocked = i + 3 < len(state) and j - 3 >= 0 and state[i + 3][j - 3] == opponent
                if top_right_blocked or bottom_left_blocked:
                    score += 60

    return score

def def_2(state, player, opponent):
    score = 0
    # Check row
    for row in state:
        for i in range(len(row) - 1):
            if all(row[i + k] == player for k in range(2)):
                # Check bounds for left and right blocking
                left_blocked = i > 0 and row[i - 1] == opponent
                right_blocked = i + 2 < len(row) and row[i + 2] == opponent
                if left_blocked or right_blocked:
                    score += 40

    # Check col
    for i in range(len(state)):
        for j in range(len(state) - 1):
            if all(state[j + k][i] == player for k in range(2)):
                # Check bounds for top and bottom blocking
                top_blocked = j > 0 and state[j - 1][i] == opponent
                bottom_blocked = j + 2 < len(state) and state[j + 2][i] == opponent
                if top_blocked or bottom_blocked:
                    score += 40

    # Check diagonal (top-left to bottom-right)
    for i in range(len(state) - 1):
        for j in range(len(state[0]) - 1):
            if all(state[i + k][j + k] == player for k in range(2)):
                # Check bounds for top-left and bottom-right blocking
                top_left_blocked = i > 0 and j > 0 and state[i - 1][j - 1] == opponent
                bottom_right_blocked = i + 2 < len(state) and j + 2 < len(state[0]) and state[i + 2][j + 2] == opponent
                if top_left_blocked or bottom_right_blocked:
                    score += 40

    # Check diagonal (top-right to bottom-left)
    for i in range(len(state) - 1):
        for j in range(1, len(state[0])):
            if all(state[i + k][j - k] == player for k in range(2)):
                # Check bounds for top-right and bottom-left blocking
                top_right_blocked = i > 0 and j + 1 < len(state[0]) and state[i - 1][j + 1] == opponent
                bottom_left_blocked = i + 2 < len(state) and j - 2 >= 0 and state[i + 2][j - 2] == opponent
                if top_right_blocked or bottom_left_blocked:
                    score += 40

    return score

def find_open_three(state, player):
    score = 0
    # Check row
    for row in state:
        for i in range(len(row) - 2):
            if all(row[i + k] == player for k in range(3)):
                if (i-1 >= 0 and row[i-1] == 0) and (i+3 < len(row) and row[i+3] == 0):
                    score += 300  # Cộng điểm cho "open three"

    # Check col
    for i in range(len(state)):
        for j in range(len(state) - 2):
            if all(state[j + k][i] == player for k in range(3)):
                if (j-1 >= 0 and state[j-1][i] == 0) and (j+3 < len(state) and state[j+3][i] == 0):
                    score += 300  # Cộng điểm cho "open three"

    # Check diagonal (top-left to bottom-right)
    for i in range(len(state) - 2):
        for j in range(len(state[0]) - 2):
            if all(state[i + k][j + k] == player for k in range(3)):
                if (i-1 >= 0 and j-1 >= 0 and state[i-1][j-1] == 0) and (i+3 < len(state) and j+3 < len(state[0]) and state[i+3][j+3] == 0):
                    score += 300  # Cộng điểm cho "open three"

    # Check diagonal (top-right to bottom-left)
    for i in range(len(state) - 2):
        for j in range(2, len(state[0])):
            if all(state[i + k][j - k] == player for k in range(3)):
                if (i-1 >= 0 and j+1 < len(state[0]) and state[i-1][j+1] == 0) and (i+3 < len(state) and j-3 >= 0 and state[i+3][j-3] == 0):
                    score += 300  # Cộng điểm cho "open three"

    return score

# should be exclusive for 5x5 board
def find_open_four(state, player):
    score = 0
    # Check row
    for row in state:
        for i in range(len(row) - 3):
            if all(row[i + k] == player for k in range(4)):
                if (i-1 >= 0 and row[i-1] == 0) and (i+4 < len(row) and row[i+4] == 0):
                    score += 500  # Cộng điểm cho "open four"

    # Check col
    for i in range(len(state)):
        for j in range(len(state) - 3):
            if all(state[j + k][i] == player for k in range(4)):
                if (j-1 >= 0 and state[j-1][i] == 0) and (j+4 < len(state) and state[j+4][i] == 0):
                    score += 500  # Cộng điểm cho "open four"

    # Check diagonal (top-left to bottom-right)
    for i in range(len(state) - 3):
        for j in range(len(state[0]) - 3):
            if all(state[i + k][j + k] == player for k in range(4)):
                if (i-1 >= 0 and j-1 >= 0 and state[i-1][j-1] == 0) and (i+4 < len(state) and j+4 < len(state[0]) and state[i+4][j+4] == 0):
                    score += 500  # Cộng điểm cho "open four"

    # Check diagonal (top-right to bottom-left)
    for i in range(len(state) - 3):
        for j in range(3, len(state[0])):
            if all(state[i + k][j - k] == player for k in range(4)):
                if (i-1 >= 0 and j+1 < len(state[0]) and state[i-1][j+1] == 0) and (i+4 < len(state) and j-4 >= 0 and state[i+4][j-4] == 0):
                    score += 500  # Cộng điểm cho "open four"

    return score

def random_move(state):
    actions = empty_cells(state)
    return random.choice(actions)

def evaluate_dynamic(state):
    score = 0
    if wins(state,DYNAMIC):
        score += 2000
    if wins(state, OPPONENT):
        score -= 1500
    if find_open_n(state, DYNAMIC):
        score += 800
    if find_open_n(state,OPPONENT):
        score -= 600
    connect_2 = check_2(state, DYNAMIC)
    score += connect_2
    connect_3 = check_3(state, DYNAMIC)
    score += connect_3
    connect_2 = check_2(state, OPPONENT)
    score -= connect_2
    connect_3 = check_3(state, OPPONENT)
    score -= connect_3
    defend = def_3(state, OPPONENT, DYNAMIC)
    score += defend
    defend = def_2(state, OPPONENT, DYNAMIC)
    score += defend
    open_three = find_open_three(state, DYNAMIC)
    score += open_three
    open_four = find_open_four(state, DYNAMIC)
    score += open_four
    return score

def render(state,c_choice, h_choice):
    choices = {
        1 : h_choice,
        2 : c_choice,
        0: ' '
    }
    line = '---------------------------------------------'
    print(line)
    for row in state:
        for col in row:
            symbol = choices[col]
            print('|',symbol,'|',end='')
        print()
        print(line)

def encode_state(state):
    return tuple(tuple(row) for row in state)

def set_move(x,y,player):
    if valid_move(x,y):
        board[x][y] = player
        return True
    return False


def copy_board(state):
    return copy.deepcopy(state)

def check_winner(state):
    global dynamic_score, opponent_score
    if wins(state, DYNAMIC):
        print("DYNAMIC WINS")
        dynamic_score += 1
    elif wins(state, OPPONENT):
        print("DYNAMIC'S OPPONENT WINS")
        opponent_score += 1
    else:
        print("IT'S A DRAW")
    return

def reset():
    global board
    board = [[0 for _ in range(size)] for _ in range(size)]

def backup_policy(state):
    board_cp = copy_board(state)

    best_action = None
    best_value = -infinity

    actions = empty_cells(board_cp)
    for action in actions:
        x, y = action[0], action[1]
        board_cp[x][y] = DYNAMIC
        value = evaluate_dynamic(board_cp)
        if value > best_value:
            best_action = action
            best_value = value
        board_cp[x][y] = 0
    
    return best_action
        
def q_learning_policy(epsilon, state):
    actions = empty_cells(state)
    if random.random() < epsilon:
        return random.choice(actions)
    else:
        encoded_state = encode_state(state)
        filtered_q_values = {key: value for key, value in q_values.items() if key[0] == encoded_state}
        if filtered_q_values:
            max_value = max(filtered_q_values.values())
            max_actions = [key for key, value in filtered_q_values.items() if value == max_value]
            best_action = random.choice(max_actions)
            return [best_action[1], best_action[2]]
        else:
            return backup_policy(state)

def game_with_q_learning(func, c_choice, h_choice, episode, decay_rate=0.01, alpha=0.1, gamma = 0.99):
    epsilon = initial_epsilon * math.e ** (-decay_rate * episode)
    print(f'current epsilon:{epsilon}')
    action = q_learning_policy(epsilon, board)
    while not game_over(board) and len(empty_cells(board)) > 0:
        x, y = action[0], action[1]
        tuple_action = (x, y)
        key = (encode_state(board), *tuple_action)
        set_move(x, y, DYNAMIC)
        reward = evaluate_dynamic(board)
        render(board, c_choice, h_choice)
        if game_over(board) or len(empty_cells(board)) == 0:
            q_values[key] = q_values.get(key, 0) + alpha * (reward - q_values.get(key, 0))
            break
        move = func(board)
        set_move(move[0], move[1], OPPONENT)
        render(board, c_choice, h_choice)
        if game_over(board) or len(empty_cells(board)) == 0:
            q_values[key] = q_values.get(key, 0) + alpha * (reward - q_values.get(key, 0))
            break

        encoded_next_state = encode_state(board)
        possible_actions = empty_cells(board)
        next_q_values = [q_values.get((encoded_next_state, action[0], action[1]), 0) for action in possible_actions]
        best_next_q = max(next_q_values) if next_q_values else 0

        q_values[key] = q_values.get(key, 0) + alpha * (reward + gamma * best_next_q - q_values.get(key, 0))

        action = q_learning_policy(epsilon, board)

    check_winner(board)
    reset()

def main():
    global board
    h_choice = 'X'
    c_choice = 'O'
    for i in range(number_of_games):
        game_with_q_learning(random_move, c_choice, h_choice, i)
        print(f'{i}th game')
    print(f'final score: dynamic: {dynamic_score} - opponent: {opponent_score}')

if __name__ == '__main__':
    main()
# Out:
# current epsilon:0.1
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 0th game
# current epsilon:0.09900498337491681
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 1th game
# current epsilon:0.09801986733067553
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 2th game
# current epsilon:0.09704455335485082
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 3th game
# current epsilon:0.09607894391523232
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 4th game
# current epsilon:0.09512294245007141
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# |   || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# | O || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# | O || X ||   |
# ---------------------------------------------
# |   ||   || X |
# ---------------------------------------------
# ---------------------------------------------
# | X || O || O |
# ---------------------------------------------
# | O || X ||   |
# ---------------------------------------------
# |   ||   || X |
# ---------------------------------------------
# ---------------------------------------------
# | X || O || O |
# ---------------------------------------------
# | O || X || X |
# ---------------------------------------------
# |   ||   || X |
# ---------------------------------------------
# ---------------------------------------------
# | X || O || O |
# ---------------------------------------------
# | O || X || X |
# ---------------------------------------------
# | O ||   || X |
# ---------------------------------------------
# ---------------------------------------------
# | X || O || O |
# ---------------------------------------------
# | O || X || X |
# ---------------------------------------------
# | O || X || X |
# ---------------------------------------------
# IT'S A DRAW
# 5th game
# current epsilon:0.09417645335842488
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 6th game
# current epsilon:0.09323938199059484
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | O || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O || O || O |
# ---------------------------------------------
# DYNAMIC'S OPPONENT WINS
# 7th game
# current epsilon:0.09231163463866358
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# DYNAMIC WINS
# 8th game
# current epsilon:0.09139311852712283
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || X ||   |
# ---------------------------------------------
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | O || X ||   |
# ---------------------------------------------
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | O || X ||   |
# ---------------------------------------------
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# | O || X ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# | O || X ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# | O || X || O |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | O || X || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | O || X || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || O || X |
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | O || X || O |
# ---------------------------------------------
# IT'S A DRAW
# 9th game
# current epsilon:0.09048374180359596
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# DYNAMIC WINS
# 10th game
# current epsilon:0.08958341352965282
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# DYNAMIC'S OPPONENT WINS
# 11th game
# current epsilon:0.08869204367171575
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 12th game
# current epsilon:0.08780954309205613
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || X || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   || X || O |
# ---------------------------------------------
# DYNAMIC'S OPPONENT WINS
# 13th game
# current epsilon:0.0869358235398806
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 14th game
# current epsilon:0.08607079764250579
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | O || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | O || X ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | O || X ||   |
# ---------------------------------------------
# | O || X ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 15th game
# current epsilon:0.08521437889662115
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# DYNAMIC WINS
# 16th game
# current epsilon:0.08436648165963838
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 17th game
# current epsilon:0.0835270211411272
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 18th game
# current epsilon:0.08269591339433624
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# DYNAMIC'S OPPONENT WINS
# 19th game
# current epsilon:0.0818730753077982
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 20th game
# current epsilon:0.08105842459701872
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# DYNAMIC WINS
# 21th game
# current epsilon:0.08025187979624786
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 22th game
# current epsilon:0.07945336025033341
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 23th game
# current epsilon:0.07866278610665535
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O || O |
# ---------------------------------------------
# DYNAMIC WINS
# 24th game
# current epsilon:0.0778800783071405
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | X || O || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | X || O || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 25th game
# current epsilon:0.07710515858035663
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 26th game
# current epsilon:0.07633794943368533
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 27th game
# current epsilon:0.07557837414557256
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 28th game
# current epsilon:0.07482635675785652
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 29th game
# current epsilon:0.0740818220681718
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 30th game
# current epsilon:0.07334469562242893
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O || O |
# ---------------------------------------------
# DYNAMIC WINS
# 31th game
# current epsilon:0.0726149037073691
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || X ||   |
# ---------------------------------------------
# | O || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || X ||   |
# ---------------------------------------------
# | O || O || X |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | O || X ||   |
# ---------------------------------------------
# | O || O || X |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O || X ||   |
# ---------------------------------------------
# | O || O || X |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O || X || O |
# ---------------------------------------------
# | O || O || X |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# | O || X || O |
# ---------------------------------------------
# | O || O || X |
# ---------------------------------------------
# DYNAMIC WINS
# 32th game
# current epsilon:0.07189237334319262
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 33th game
# current epsilon:0.07117703227626097
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || O |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ...
# DYNAMIC'S OPPONENT WINS
# 986th game
# current epsilon:5.170272861446199e-06
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 987th game
# current epsilon:5.118827786912646e-06
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 988th game
# current epsilon:5.0678945994234875e-06
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# DYNAMIC WINS
# 989th game
# current epsilon:5.0174682056175315e-06
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# DYNAMIC WINS
# 990th game
# current epsilon:4.967543562813374e-06
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# | O ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 991th game
# current epsilon:4.918115678505132e-06
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# | O ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 992th game
# current epsilon:4.869179609863184e-06
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# | O ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# | O ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 993th game
# current epsilon:4.820730463239885e-06
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 994th game
# current epsilon:4.772763393680191e-06
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# | O ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 995th game
# current epsilon:4.725273604437189e-06
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   || O |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 996th game
# current epsilon:4.678256346492372e-06
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 997th game
# current epsilon:4.6317069180807645e-06
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# | X || O ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 998th game
# current epsilon:4.585620664220734e-06
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X ||   ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O ||   |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X ||   |
# ---------------------------------------------
# |   || O || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# ---------------------------------------------
# | X || X || X |
# ---------------------------------------------
# |   || O || O |
# ---------------------------------------------
# |   ||   ||   |
# ---------------------------------------------
# DYNAMIC WINS
# 999th game
# final score: dynamic: 858 - opponent: 94

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize = (10,5))
x = ['Q-learning', 'OPPONENT']
y = [round(dynamic_score / 10000 * 100,4) , round(opponent_score / 10000 * 100,4)]
colors = ['blue', 'orange']
plt.bar(x=x, height=y, label=['Q-learning', 'Opponent'], color = colors)
plt.legend()
plt.show()
